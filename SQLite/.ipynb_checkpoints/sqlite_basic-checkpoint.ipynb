# %% [markdown]
# # Sqlite basic

# %%
import sqlite3
con = sqlite3.connect('starbucks.sqlite')
cursor = con.cursor()

# %% [markdown]
# ## select from

# %%
# select from DB
cursor.execute("SELECT * FROM pushdata;")
results=cursor.fetchall()

# %%
results
# Out:
# [(u'tw00527876', u'\u63a8\x1b\r\n', 1.0, u'03/04 21:34'),
#  (u'dSnAil', u'\u7d71\u4e00\uff1a\r\n', 1.0, u'03/04 21:34'),
#  (u'tetsu0401', u'\u5594\u5594\u5594\u5594\uff01\r\n', 1.0, u'03/04 21:34'),
#  (u'dnek',
#   u'\u53cd\u89c0\u4e2d\u592e\u662f\u6709\u8ab0\u4f86\u7576\u98df\u5b89\u59d4\u54e1\uff1f\x1b\r\n',
#   0.0,
#   u'03/04 21:34'),
#  (u'lebiged',
#   u'9.2\uff1a\u4e0d\u662f\u570b\u6c11\u9ee8\u4e0d\u80fd\u7403\u54e1\u517c\u88c1\u5224\uff01\x1b\r\n',
#   1.0,
#   u'03/04 21:34'),
#  (u'zeze', u'\u5594\u5594\uff01\x1b\r\n', 0.0, u'03/04 21:34'),
#  (u'ddd87521',
#   u'\u51fa\u73fe\u60f9!!!!!!!!!!!!!\u6012\u5403\u7fa9\u7f8e\x1b\r\n',
#   0.0,
#   u'03/04 21:34'),
#  (u'yaya', u'\u8b9a\x1b\r\n', 0.0, u'03/04 21:36'),
#  (u'Doukyusei',
#   u'\u5594\u5594\u5594\u5594!!!!\u9019\u4e0b\u98df\u5b89\u771f\u7684\u6709\u5e0c\u671b\u4e86!!!!\u611f\u52d5!!!!\x1b\r\n',
#   1.0,
#   u'03/04 21:36'),
#  (u'kuankubank',
#   u'\u885b\u798f\u90e8\u98df\u85e5\u7f72\u7f72\u9577\u59dc\u90c1\u7f8e................\x1b\r\n',
#   -1.0,
#   u'03/04 21:37'),
#  (u'buchholiz', u'\u63a8\x1b\r\n', 1.0, u'03/04 21:37'),
#  (u'kiergh',
#   u'\u5b98\u5546\u52fe\u7d50\u6211\u72a7\u7272\u4e00\u9ede\u5148\u628a\u7fa9\u7f8e\u9580\u5e02\u8cb7\u5149\u5c2c\u9322\u8ddf\u4e0a!!!\x1b\r\n',
#   1.0,
#   u'03/04 21:38'),
#  (u'iXXXXGAY5566',
#   u'\u5927\u5bb6\u6700\u5e79\u7684\u59dc\u90c1\u7f8e\u4e5f\u597d\u5f80\u597d\u8655\u60f3\u662f\u8981\u9ede\u9192\u7260\x1b\r\n',
#   0.0,
#   u'03/04 21:38'),
#  (u'Francis11', u'push\x1b\r\n', 1.0, u'03/04 21:38'),
#  (u'yun0215', u'\uff01\uff01\uff01\uff01\x1b\r\n', 1.0, u'03/04 21:38'),
#  (u'fvfv',
#   u'\u6012\u8cb7\u7fa9\u7f8e\u5169\u767e\u6297\u8b70\x1b\r\n',
#   1.0,
#   u'03/04 21:39'),
#  (u'yaya', u'\u8b9a\x1b\r\n', 1.0, u'03/04 21:39'),
#  (u'creulfact',
#   u'\u7cdf\u7cd59.2\u8db4:\u9019\u662f\u5b98\u5546\u52fe\u7d50!\x1b\r\n',
#   1.0,
#   u'03/04 21:39'),
#  (u'meowchen', u'!!!\x1b\r\n', 1.0, u'03/04 21:39'),
#  (u'LoveMakeLove', u'\u795e\u4e86\x1b\r\n', 1.0, u'03/04 21:39'),
#  (u'yun0215',
#   u'\u4f60\u628a\u4eba\u90fd\u6436\u8d70\u4e86\uff0c\u4e2d\u592e\u53ea\u597d\u7528\u7d71\u4e8c\u9802\u65b0\u7684\u4eba\u4e86...\x1b\r\n',
#   0.0,
#   u'03/04 21:40'),
#  (u'greatgatsby',
#   u'\u7fa9\u7f8eX\u67ef\u6587\u54f2!!!\u9019\u500b\u54c1\u724c\u53eb\u826f\u5fc3!!!\x1b\r\n',
#   1.0,
#   u'03/04 21:40'),
#  (u'Simakui', u'\u5594\u5594\u5594\x1b\r\n', 1.0, u'03/04 21:40'),
#  (u'chungyiju',
#   u'\u52a0\u6cb9\u597d\u597d\u505a\x1b\r\n',
#   1.0,
#   u'03/04 21:40'),
#  (u'taimu', u'\r\n', 1.0, u'03/04 21:40'),
#  (u'roveralex', u'\u63a8\uff01\uff01\r\n', 1.0, u'03/04 21:40'),
#  (u'fanlander',
#   u'9.2os:\u8d95\u5feb\u6ce2\u9ad2\u6c34\u4e0d\u7136\u5c31gg\u60f9\x1b\r\n',
#   1.0,
#   u'03/04 21:41'),
#  (u'yeahoviovi',
#   u'\u6c7a\u5b9a\u7528\u9322\u62b5\u5236\u7fa9\u7f8e\uff01\uff01\uff01\x1b\r\n',
#   1.0,
#   u'03/04 21:41'),
#  (u'yaya', u'\u52a0\u6cb9\x1b\r\n', 1.0, u'03/04 21:41'),
#  (u'jevix', u'\u63a8\u6012\u8cb7\u9bae\u5976\x1b\r\n', 1.0, u'03/04 21:42'),
#  (u'v19791119',
#   u'\u9019\u9663\u5bb9\u61c9\u8a72\u662f\u53f2\u4e0a\u6700\u5f37\uff0c\u4e4b\u524d\u592a\u5f31\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 21:43'),
#  (u'DFTT',
#   u'\u9019\u4e0d\u53eb\u5b98\u5546\u52fe\u7d50\u4ec0\u9ebc\u624d\u53eb\u5b98\u5546\u52fe\u7d50?(\u8815\u52d5)\x1b\r\n',
#   0.0,
#   u'03/04 21:43'),
#  (u'sa87a16', u'\u8d77\u98a8\u5566\x1b\r\n', 1.0, u'03/04 21:44'),
#  (u'chihchuan', u'\u63a8\x1b\r\n', 1.0, u'03/04 21:44'),
#  (u'zebra7',
#   u'\u5e79\u90fd\u7d66\u4f60\u73a9\u5c31\u597d\u5566\u592a\u5f37\u4e86\u5566\x1b\r\n',
#   1.0,
#   u'03/04 21:44'),
#  (u'xfirex',
#   u'\u63a8\u53ef\u60dc\u6709\u90a3\u500b\u59d3\u59dc\u7684\x1b\r\n',
#   1.0,
#   u'03/04 21:45'),
#  (u'dinex', u'\x1b\r\n', 1.0, u'03/04 21:45'),
#  (u'fifi0828',
#   u'\u679c\u7136\u6c92\u9078\u932f\u4eba\x1b\r\n',
#   1.0,
#   u'03/04 21:46'),
#  (u'Jackyfans',
#   u'\u53ef\u60e1\uff0c\u6012\u5403\u7fa9\u7f8e\x1b\r\n',
#   1.0,
#   u'03/04 21:46'),
#  (u'foolfighter',
#   u'\u6293\u5230\u4e86\uff0c\u5716\u5229\u5ee0\u5546\uff0c\u79d1\u5c41\u9000\u9078\uff01\x1b\r\n',
#   0.0,
#   u'03/04 21:48'),
#  (u'pagenotfound',
#   u'\u885b\u798f\u90e8\u98df\u85e5\u7f72\u53cd\u904e\u4f86\u60f3\u53ef\u7531\u5730\u65b9\u63a8\u52d5\u4e2d\u592e\u4fee\u6cd5\x1b\r\n',
#   1.0,
#   u'03/04 21:49'),
#  (u'MAGICMCGRADY', u'\u8b9a\x1b\r\n', 1.0, u'03/04 21:50'),
#  (u'dragon2000',
#   u'\u6c23\u6b7b\u6211\u4e86\u8cb7\u500b\u5de7\u514b\u529b\u6ce1\u8299\u6d29\u6068\x1b\r\n',
#   1.0,
#   u'03/04 21:50'),
#  (u'crusaders811',
#   u'\u884c\u653f\u9662\u7684\u98df\u5b89\u8fa6\u516c\u5ba4\u9084\u5728\u55ce????\x1b\r\n',
#   1.0,
#   u'03/04 21:50'),
#  (u'eric2099',
#   u'\u5c4c\u6253\u99ac\u72d7\u98df\u5b89\u8fa6\u516c\u5ba4\x1b\r\n',
#   1.0,
#   u'03/04 21:50'),
#  (u'shark5566', u'\u63a8\x1b\r\n', 1.0, u'03/04 21:51'),
#  (u'rock666', u'\u63a8\u554a\x1b\r\n', 1.0, u'03/04 21:51'),
#  (u'kiki2125', u'\u86c6\u86c6\u8815\u52d5\u4e2d\r\n', 1.0, u'03/04 21:52'),
#  (u'joanying',
#   u'\u63a8\uff0c\u611f\u52d5\u67efP\u826f\u77e5\u7684\u884c\u52d5\u529b!\r\n',
#   1.0,
#   u'03/04 21:53'),
#  (u'Tuscany', u'\u63a8\x1b\r\n', 1.0, u'03/04 21:53'),
#  (u'amop', u'\u63a8\uff01\uff01\x1b\r\n', 1.0, u'03/04 21:54'),
#  (u'shiang28',
#   u'\u6012\u8cb7\u5de7\u514b\u529b\u9165\u53ca\u5e03\u4e01\u6d88\u6c23\x1b\r\n',
#   1.0,
#   u'03/04 21:54'),
#  (u'headiron', u'\u592a\u795e\u4e86\x1b\r\n', 1.0, u'03/04 21:54'),
#  (u'epistemie', u'\u63a8\x1b\r\n', 0.0, u'03/04 21:54'),
#  (u'c10177', u'\u63a8!\x1b\r\n', 1.0, u'03/04 21:56'),
#  (u'kenyin', u'\u63a8\x1b\r\n', 1.0, u'03/04 21:56'),
#  (u'unreal29', u'\u54c7!\u63a8\u7fa9\u7f8e!\x1b\r\n', 1.0, u'03/04 21:56'),
#  (u'collector', u'\x1b\r\n', 1.0, u'03/04 21:57'),
#  (u'ymx3xc',
#   u'\u592a\u53ef\u60e1\u4e86!\u53ea\u597d\u6012\u8cb7\u8cb7\u4e09\u76d2\u7fa9\u7f8e\u6e6f\u5713\x1b\r\n',
#   1.0,
#   u'03/04 21:57'),
#  (u'dearevan',
#   u'\u5e79\u683c\u5c40\u6bd4\u7e3d\u7d71\u5e9c\u9084\u5927!\x1b\r\n',
#   1.0,
#   u'03/04 21:57'),
#  (u'ryan0222',
#   u'\u885b\u798f\u90e8\u98df\u85e5\u7f72\u7f72\u9577\u59dc\u90c1\u7f8e\x1b\r\n',
#   -1.0,
#   u'03/04 21:57'),
#  (u'pagenotfound',
#   u'\u6211\u611f\u53d7\u5230\u67efP\u5c0d\u53f0\u7063\u9019\u584a\u571f\u5730\u7684\u611b\x1b\r\n',
#   1.0,
#   u'03/04 21:57'),
#  (u'CORSA',
#   u'\u4e0d\u7ba1\u5982\u4f55\u9084\u662f\u8981\u6709\u4e00\u4e9b"\u4e0d\u652f\u6301\u8005"\u4ee3\u8868\u963f\x1b\r\n',
#   0.0,
#   u'03/04 21:58'),
#  (u'shadow666',
#   u'\u5e79\uff01\uff01\uff01\u6012\u5403\u5c0f\u6ce1\u8299\uff01\uff01\uff01\x1b\r\n',
#   1.0,
#   u'03/04 21:58'),
#  (u'vimeo',
#   u'\u54e6\u54e6\u54e6\u54e6\uff01\uff01\uff01\x1b\r\n',
#   1.0,
#   u'03/04 21:58'),
#  (u'julia66', u'\x1b\r\n', 1.0, u'03/04 21:59'),
#  (u'dafo', u'..........\u826f\u5fc3\u4f86\u4e86\x1b\r\n', 0.0, u'03/04 21:59'),
#  (u'meowmeowgo',
#   u'\u592a\u795e\u5566\uff3c(^o^)\uff0f\x1b\r\n',
#   1.0,
#   u'03/04 21:59'),
#  (u'zxcvf', u'\u53ea\u80fd\u63a8\u4e86\x1b\r\n', 1.0, u'03/04 22:00'),
#  (u'HornyDragon', u'\u592a\u795e\x1b\r\n', 1.0, u'03/04 22:00'),
#  (u'victoryman', u'\u54c8\u54c8\u592a\u795e\u4e86\r\n', 1.0, u'03/04 22:01'),
#  (u'ace4', u'\u63a8\x1b[23;26H\r\n', 0.0, u'03/04 22:01'),
#  (u'higameboy', u'RRRRRRRRRRRRRRRRRRRRRRRRRRRR\x1b\r\n', 1.0, u'03/04 22:01'),
#  (u'oicecnir',
#   u'\u54ce..\u5f88\u6b63\u5e38\u8a72\u505a\u7684\u4e8b..\u7adf\u7136\u76f4\u63a5\u63a8\u7206...\u4e2d\u592e\u653f\u5e9c\u5230\u5e95\u591a\u721b\x1b\r\n',
#   1.0,
#   u'03/04 22:01'),
#  (u'GenghisKhan',
#   u'mmmmmmmmmmmmmmmmmm\u56e7\u5b98\u5546\u52fe\u7d50\u56e7mmmmmmmmmmmmmmmmm\x1b\r\n',
#   0.0,
#   u'03/04 22:01'),
#  (u'blueweave',
#   u'\u4e0d\u628a\u7fa9\u7f8e\u5403\u5012\u4e0d\u884c\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 22:02'),
#  (u'leontj', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:02'),
#  (u'yduiy', u'\x1b\r\n', 1.0, u'03/04 22:03'),
#  (u'elle',
#   u'\u4e0a\u6b21\u807d\u7fa9\u7f8e\u7684\u7ba1\u7406\u7406\u5ff5\u5c31\u8ddf\u67efp\u5f88\u50cf\u963f\x1b\r\n',
#   1.0,
#   u'03/04 22:03'),
#  (u'kimitoboku', u'\u63a8\u554a!!!!!\x1b\r\n', 1.0, u'03/04 22:03'),
#  (u'miloisgood', u'\\\u7fa9\u7f8e/\x1b\r\n', 1.0, u'03/04 22:03'),
#  (u'jeneaqa1', u'\u8b9a\u5566\x1b\r\n', 1.0, u'03/04 22:05'),
#  (u'love1987817', u'\u54c8\u54c8\x1b\r\n', 1.0, u'03/04 22:05'),
#  (u'TIGER228',
#   u'\u5317\u5e02\u5e9c\u6709\u773c\u5149\x1b\r\n',
#   1.0,
#   u'03/04 22:05'),
#  (u'weboau', u'\u826f\u5fc3\u4f86\u4e86QQ\x1b\r\n', 1.0, u'03/04 22:06'),
#  (u'iMANIA', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:06'),
#  (u'ecgklf', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:07'),
#  (u'sediments',
#   u'\u5b98\u5546\u52fe\u7d50\u770b\u6211\u600e\u9ebc\u7528\u65b0\u53f0\u5e63\u4e0b\u67b6\u4f60\u7684\u8ca8\x1b\r\n',
#   1.0,
#   u'03/04 22:07'),
#  (u'skyringcha',
#   u'\u770b\u4f86\u4ee5\u5f8c\u53ea\u80fd\u5403\u53f0\u5317\u5e02\u8a8d\u8b49\u904e\u7684\u98df\u7269\u4e86\uff01\x1b\r\n',
#   1.0,
#   u'03/04 22:08'),
#  (u'mayuyuki', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:08'),
#  (u'fytnship',
#   u'\u5317\u5e02\u5e9c\u958b\u5916\u639b?\x1b\r\n',
#   1.0,
#   u'03/04 22:08'),
#  (u'garcia',
#   u'\u8840\u58d3\u85e5\u8acb\u6e96\u5099\u597d\x1b\r\n',
#   1.0,
#   u'03/04 22:08'),
#  (u'Refauth',
#   u'\u256e(\ufe40_\ufe40")\u256d\u5230\u5e95\u662f\u5e02\u9577\u9084\u662f\u7e3d\u7d71\u554a\uff1f\x1b\r\n',
#   1.0,
#   u'03/04 22:08'),
#  (u'prkfcpr',
#   u'\u5e0c\u671b\u7fa9\u7f8e\u4e0d\u8981\u56e0\u6b64\u88ab\u67d3\u9ed1\r\n',
#   1.0,
#   u'03/04 22:10'),
#  (u'harryrrah',
#   u'\u9019\u662f\u570b\u5bb6\u7b49\u7d1a\u4e86\uff0c\u53f0\u5317\u4eba\u771f\u5e78\u798f\r\n',
#   1.0,
#   u'03/04 22:10'),
#  (u'skyringcha',
#   u'\u9663\u5bb9\u597d\u5805\u5f37\u963f\uff01\x1b\r\n',
#   1.0,
#   u'03/04 22:10'),
#  (u'frogha1',
#   u'\u5e79!\u7fa9\u7f8e\u61c9\u8a72\u64d4\u4efb\u4e2d\u592e\u7d1a\u7684\u98df\u5b89\u59d4\u54e1\u624d\u5c0d!\u7b49\u8521\u82f1\u6587\u4e86!\x1b\r\n',
#   0.0,
#   u'03/04 22:11'),
#  (u'hyperionii', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:11'),
#  (u'frogha1',
#   u'\u7fa9\u7f8e\u7684\u610f\u898b,\u5982\u7981\u6b62\u6539\u9020\u57fa\u56e0\u7684\u8fb2\u4f5c\u7269,\u90fd\u662f\u570b\u5bb6\u5c64\u7d1a\u7684\x1b\r\n',
#   0.0,
#   u'03/04 22:12'),
#  (u'frogha1',
#   u'\u53bb\u53f0\u5317\u5e02\u64d4\u4efb\u59d4\u54e1\u4e5f\u6c92\u7528\x1b\r\n',
#   0.0,
#   u'03/04 22:12'),
#  (u'cychine', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:13'),
#  (u'pagenotfound',
#   u'\u8521\u82f1\u6587\u9078\u4e0a\u518d\u8aaa\x1b\r\n',
#   0.0,
#   u'03/04 22:13'),
#  (u'pftmax', u'\u65e9\u8a72\u91cd\u7528\u4e86\x1b\r\n', 1.0, u'03/04 22:13'),
#  (u'embracepl', u'\x1b\r\n', 1.0, u'03/04 22:13'),
#  (u'dodo6',
#   u'\u6709\u7fa9\u7f8e\u7e3d\u7d93\u7406\u5f88\u597d\x1b\r\n',
#   1.0,
#   u'03/04 22:13'),
#  (u'cttw19',
#   u'KMT:\u6709\u54b1\u5011\u9b4f\u8463\u53b2\u5bb3\u9ebc\x1b\r\n',
#   1.0,
#   u'03/04 22:14'),
#  (u'Taidalmc',
#   u'\u5e79\u4eba\u624d\u90fd\u96c6\u4e2d\u5230\u53f0\u5317\u5e02\u4e86\u5176\u4ed6\u5404\u5730\u8981\u600e\u9ebc\u8fa6\x1b\r\n',
#   1.0,
#   u'03/04 22:15'),
#  (u'SHIU0315',
#   u'\u5e79\u592a\u8b9a\u4e86!!!!!!!\x1b\r\n',
#   1.0,
#   u'03/04 22:15'),
#  (u'Su22', u'push\x1b\r\n', 1.0, u'03/04 22:15'),
#  (u'yeh0416',
#   u'\u5c0f\u6ce1\u8299\u6211\u7684\u5225\u6436\x1b\r\n',
#   1.0,
#   u'03/04 22:16'),
#  (u'deathsman',
#   u'\u9019\u9ebc\u660e\u986f\u7684\u5b98\u5546\u52fe\u7d50\u9084\u4e0d\u67e5\uff1f\u6012\u8cb7\u5169\u76d2\u5c0f\u6ce1\u8299\u5403\u6389\u6d29\u61a4\x1b\r\n',
#   1.0,
#   u'03/04 22:16'),
#  (u'ChrisLiu', u'\u63a8\uff01\x1b\r\n', 1.0, u'03/04 22:17'),
#  (u'STi2011',
#   u'\u5e79\u7fa9\u7f8e\u51fa\u982d\u5929\u4e86\x1b\r\n',
#   0.0,
#   u'03/04 22:17'),
#  (u'yaya', u'\uff01\x1b\r\n', 1.0, u'03/04 22:19'),
#  (u'terresa916', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:20'),
#  (u'mjumju',
#   u'\u5594\u5594\u5594!!!\u6211\u8981\u642c\u5bb6\u5230\u53f0\u5317!!!!\x1b\r\n',
#   1.0,
#   u'03/04 22:20'),
#  (u'wrbfndkdo', u'\u63a8\r\n', 1.0, u'03/04 22:20'),
#  (u'aimgel',
#   u'\u9127\u5bb6\u57fa\u5230\u5e95\u6703\u4e0d\u6703\u88ab\u64cd\u6b7b\u554a\r\n',
#   1.0,
#   u'03/04 22:21'),
#  (u'suge',
#   u'\u4e2d\u592e:\u6211\u5011\u6709\u9802\u65b0\u7684\u98df\u5b89\u57fa\u91d1\uff0c\u7576\u7136\u4e5f\u8981\u8acb\u9b4f\u5bb6\u7576\u53ec\u96c6\u4eba\x1b\r\n',
#   1.0,
#   u'03/04 22:22'),
#  (u'guepard',
#   u'\u5927\uff01\uff01\uff01\uff01\u63a8\uff01\uff01\uff01\uff01\x1b\r\n',
#   1.0,
#   u'03/04 22:22'),
#  (u'Lazzaro',
#   u'\u60f3\u79fb\u6c11\u53bb\u53f0\u5317\x1b\r\n',
#   1.0,
#   u'03/04 22:23'),
#  (u'gsx7777777',
#   u'\u6012\u8cb7\u5149\u7fa9\u7f8e\u5c0f\u6ce1\u8299\x1b\r\n',
#   1.0,
#   u'03/04 22:24'),
#  (u'Jing0733',
#   u'\u751f\u6c23\uff01\u6012\u5403\u5de7\u514b\u529b\u6ce1\u8299\x1b\r\n',
#   1.0,
#   u'03/04 22:25'),
#  (u'allloveme', u'cool\x1b\r\n', 1.0, u'03/04 22:25'),
#  (u'Kennyq',
#   u'\u8b9a\u5566\uff01\u98df\u5b89\u7d42\u65bc\u6709\u6551\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 22:25'),
#  (u'Samael', u'\x1b\r\n', 1.0, u'03/04 22:26'),
#  (u'tzuchun0214', u'\u63a8\u554a\x1b\r\n', 1.0, u'03/04 22:26'),
#  (u'aa1477888',
#   u'\u6709\u540d\u4efd\u4e86\u958b\u59cb\u780d\u554a!\x1b\r\n',
#   1.0,
#   u'03/04 22:27'),
#  (u'abls',
#   u'\u597d\u8036\uff01\u592a\u8b9a\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 22:27'),
#  (u'celine1234', u'\u5e25\u6c23\x1b\r\n', 1.0, u'03/04 22:27'),
#  (u'Supasizeit',
#   u'\u723d\uff0c\u8b93\u5473\u5168\u7d71\u4e00\u5168\u6578\u4e0b\u67b6\uff0c7-11\u5168\u5bb6\u6efe\u51fa\u53f0\u5317\x1b\r\n',
#   1.0,
#   u'03/04 22:27'),
#  (u'VVax', u'\x1b\r\n', 1.0, u'03/04 22:28'),
#  (u'daniel3551',
#   u'\u6b63\u76f4\u548c\u5584\u826f\u90fd\u56de\u4f86\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 22:28'),
#  (u'fangio', u'\u63a8\u554a\x1b\r\n', 1.0, u'03/04 22:28'),
#  (u'revive25',
#   u'\u9019\u624d\u5c0d\u963f\u96e3\u5f97\u627e\u5230\u4e00\u500b\u53ef\u4fe1\u4efb\u7684\u4eba\u7dad\u8b77\u98df\u5b89\u53f0\u5317\u8b9a\u5594\x1b\r\n',
#   1.0,
#   u'03/04 22:29'),
#  (u'dostey',
#   u'\u53f0\u7063\u98df\u54c1\u552f\u4e00\u6de8\u571f\x1b\r\n',
#   1.0,
#   u'03/04 22:30'),
#  (u'shadow77727', u'\u8d85\u7d1a\u731b\x1b\r\n', 1.0, u'03/04 22:30'),
#  (u'heylisa',
#   u'\u9760\u9080\u8d85\u5f37\u7684\u62c9\x1b\r\n',
#   1.0,
#   u'03/04 22:30'),
#  (u'costello',
#   u'\u53ef\u60e1\u7403\u54e1\u517c\u88c1\u5224\u5b98\u5546\u52fe\u7d50\u6700\u7cdf\u7cd5\u53c8\u5f97\u7528\u65b0\u53f0\u5e63\u5f37\u8feb\u4e0b\u67b6\x1b\r\n',
#   1.0,
#   u'03/04 22:30'),
#  (u'alwaysstrong', u'\u8b9a\uff01\r\n', 0.0, u'03/04 22:30'),
#  (u'vgbvgb', u'ohmygod\u8b9a\r\n', 1.0, u'03/04 22:30'),
#  (u'resudi',
#   u'\u5148\u5403\u500b\u5c0f\u6ce1\u8299\u58d3\u58d3\u9a5a\x1b\r\n',
#   1.0,
#   u'03/04 22:30'),
#  (u'lppal',
#   u'\u5594\u5594!!!\u98df\u5b89\u6709\u6551\u4e86!!!!\x1b\r\n',
#   1.0,
#   u'03/04 22:31'),
#  (u'kducky',
#   u'\u5403\u500b\u7fa9\u7f8e\u971c\u6dc7\u6dcb\u58d3\u58d3\u9a5a\x1b\r\n',
#   1.0,
#   u'03/04 22:31'),
#  (u'keepsmiling', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:31'),
#  (u'kis28519', u'\u8b9a\x1b\r\n', 1.0, u'03/04 22:32'),
#  (u'wayne1120',
#   u'\u7528\u65b0\u53f0\u5e63\u61f2\u7f70\u4f60\x1b\r\n',
#   1.0,
#   u'03/04 22:32'),
#  (u'Tamama56', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:33'),
#  (u'pkyosx',
#   u'\u80c3\u6d6e\u5e03:\u80c3\u786c\u885d:\u98df\u5eb5\u4f34\u4f9b\u7940:\x1b\r\n',
#   1.0,
#   u'03/04 22:33'),
#  (u'jiumee', u'\u9019\u500b\u597d\x1b\r\n', 1.0, u'03/04 22:33'),
#  (u'kktt254', u'\u9019\u9663\u5bb9\u597d\u731b\x1b\r\n', 1.0, u'03/04 22:33'),
#  (u'theEastCoast', u'y\x1b\r\n', 1.0, u'03/04 22:34'),
#  (u'apple8335',
#   u'\u5594\u5594\u5594\u5594\u5594\u6709\u9ede\u5f37\x1b\r\n',
#   1.0,
#   u'03/04 22:34'),
#  (u'fisht',
#   u'\u5c31\u7518\u5fc3\u7684\uff01\uff01\uff01\x1b\r\n',
#   1.0,
#   u'03/04 22:34'),
#  (u'keane9112',
#   u'\u6839\u672c\u6bd4\u7e3d\u7d71\u5e9c\u9084\u8981\u6709\u7528...\x1b\r\n',
#   1.0,
#   u'03/04 22:35'),
#  (u'shinobunodok',
#   u'\u90a3\u500b\u4ec0\u9ebc\u98df\u5b89\u8fa6\u516c\u5ba4\u53ef\u4ee5\u64a4\u4e86\u6bd4\u7167\u5317\u5e02\u8fa6\u7406\u5c31\u597d\x1b\r\n',
#   1.0,
#   u'03/04 22:35'),
#  (u'vingfing',
#   u'\u53ef\u60e1\uff0c\u6012\u5403\u7fa9\u7f8e\uff0c\u7528\u53f0\u5e63\u64ca\u57ae\u9019\u916c\u5eb8\u7684\u5634\u81c9\x1b\r\n',
#   1.0,
#   u'03/04 22:36'),
#  (u'Singlewing',
#   u'\u98df\u5b89\u6709\u6551\u5566~!!!\x1b\r\n',
#   1.0,
#   u'03/04 22:38'),
#  (u'minbyminby',
#   u'\u5594\u5594\u5594\u5594\u6211\u5011\u4f86\u5403\u57ae\u7fa9\u7f8e!!!\x1b\r\n',
#   1.0,
#   u'03/04 22:39'),
#  (u'krishuang', u'\u63a8\x1b\r\n', 0.0, u'03/04 22:39'),
#  (u'rong0204', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:40'),
#  (u'DarylMorey',
#   u'\u53f0\u5317\u6709\u67ef\u6587\u54f2\u771f\u597d\x1b\r\n',
#   1.0,
#   u'03/04 22:41'),
#  (u'hsm926', u'\u8b9a\r\n', 1.0, u'03/04 22:41'),
#  (u'ajin0305', u'\u63a8\uff01\uff01\r\n', 1.0, u'03/04 22:41'),
#  (u'alibuda2014',
#   u'\u53ef\u60dc\u6797\u6770\u6a11\u91ab\u5e2b\u65e9\u901d\u8981\u4e0d\u7136\u7d55\u5c0d\u6709\u4ed6\u4e00\u5e2d\u5e6b\u6211\u5011\u628a\u95dc\x1b\r\n',
#   1.0,
#   u'03/04 22:41'),
#  (u'zz71', u'\u63a8\x1b\r\n', 0.0, u'03/04 22:41'),
#  (u'richard42',
#   u'KMT\u9084\u4e0d\u5d29\u6f70!!!\x1b\r\n',
#   0.0,
#   u'03/04 22:42'),
#  (u'Asucks',
#   u'\u592a\u8b9a\u4e86!!!!!KMT\u9019\u5783\u573e\u9ee8\u52e2\u5fc5\u5168\u9762\u5d29\u6f70\x1b\r\n',
#   1.0,
#   u'03/04 22:43'),
#  (u'Asucks',
#   u'\u5982\u679c\u4fe0\u91ab\u9084\u5728\u4e16\uff0c\u67efP\u4e00\u5b9a\u4e5f\u6703\u529b\u9080\u4ed6\x1b\r\n',
#   0.0,
#   u'03/04 22:43'),
#  (u'baddad',
#   u'\u4e7e\u4f60\u5abd\u7684\u7d71\u4e8c\u4f60\u5c4e\u5b9a\u60f9\uff01\x1b\r\n',
#   0.0,
#   u'03/04 22:43'),
#  (u'fallen1', u'\u8b9a\u5566\x1b\r\n', 1.0, u'03/04 22:44'),
#  (u'eldar', u'\x1b\r\n', 1.0, u'03/04 22:44'),
#  (u'wakou109', u'\u63a8\u63a8~\x1b\r\n', 1.0, u'03/04 22:44'),
#  (u'yulin0312', u'GJ\x1b\r\n', 1.0, u'03/04 22:46'),
#  (u'geesegeese',
#   u'\u5e79\u5403\u6b7b\u7fa9\u7f8e\x1b\r\n',
#   1.0,
#   u'03/04 22:46'),
#  (u'Azabulu',
#   u'\u96e3\u602a\u4eca\u5929\u53bb\u627e\u7d71\u4e00\u8089\u71e5\u4e0b\u67b6\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 22:46'),
#  (u'maxboy06',
#   u'\u5e79\u4f60\u5979\u5abd\u7684\u5feb\u628a\u9802\u65b0\u6839\u7d71\u4e8c\u5f04\u5012\u597d\u55ce\u5bb3\u4eba\u4e0d\u6dfa\u7684\u5783\u573e\x1b\r\n',
#   1.0,
#   u'03/04 22:48'),
#  (u'fransiceyho', u'\u8b9a\x1b\r\n', 1.0, u'03/04 22:48'),
#  (u'airflow',
#   u'\u6012\u5403\u7fa9\u7f8e\u90ed\u96ea\u8299~\x1b\r\n',
#   0.0,
#   u'03/04 22:49'),
#  (u'curly7',
#   u'\u53f0\u5317\u4eba\u597d\u5e78\u798f\x1b\r\n',
#   1.0,
#   u'03/04 22:50'),
#  (u'kiwiwoo', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:51'),
#  (u'htaedamay',
#   u'\u53ef\u60e1\u7684\u7fa9\u7f8e\u6c23\u6b7b\u6211\u60f9\u6012\u5403\u7fa9\u7f8e\u5c0f\u6ce1\u8299!!\x1b\r\n',
#   1.0,
#   u'03/04 22:52'),
#  (u'error123',
#   u'\u7fa8\u6155\u53f0\u5317\u4eba\uff01\x1b\r\n',
#   1.0,
#   u'03/04 22:52'),
#  (u'bloodmickey', u'\u63a8\x1b\r\n', 1.0, u'03/04 22:52'),
#  (u'mengjertsai',
#   u'\u5b98\u5546\u52fe\u7d50\u963f~~\u5feb\u62ff\u9214\u7968\u6559\u8a13\u7fa9\u7f8e\x1b\r\n',
#   1.0,
#   u'03/04 22:53'),
#  (u'rainbow321',
#   u'\u7d42\u65bc\u6709\u826f\u5fc3\u7684\u4eba\u51fa\u4f86\u4e86\r\n',
#   1.0,
#   u'03/04 22:53'),
#  (u'behero',
#   u'\u9019\u5c31\u662f\u67efP\u7684\u5be6\u529b\u8ddf\u865f\u53ec\u80fd\u91cf...\u5f37\u3002\r\n',
#   1.0,
#   u'03/04 22:54'),
#  (u'njrmp',
#   u'\u5927\u63a8\u9019\u540d\u55ae\u8b9a\u5566\uff01\x1b\r\n',
#   1.0,
#   u'03/04 22:55'),
#  (u'germing',
#   u'\u52a0\u6cb9\u82e5\u6490\u4e0b\u53bb\u5f04\u51fa\u5e7e\u500b\u6709\u6548\u76e3\u7763\u7684\u6cd5\u5236/\u505a\u6cd5\u5f88\u5feb\u5176\u4ed6\u7e23\x1b\r\n',
#   1.0,
#   u'03/04 22:55'),
#  (u'germing',
#   u'\u5e02\u5c31\u6703\u8ddf\u9032\u7684\x1b\r\n',
#   0.0,
#   u'03/04 22:55'),
#  (u'blxbl', u'\u6012\u5403\u7fa9\u7f8e~\x1b\r\n', 1.0, u'03/04 22:56'),
#  (u'chyou2003',
#   u'\u8d85\u5f8c\u6bc0\u9078\u67efP\u7684\u5566\uff0c\u9019\u6a23\u53f0\u5317\u8ddf\u5404\u7e23\u5e02\u5dee\u8ddd\u8b8a\u5927\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 22:56'),
#  (u'a2156700', u'12\u500b\u59d4\u5916\x1b\r\n', 0.0, u'03/04 22:57'),
#  (u'mmarty', u'awesome!!\x1b\r\n', 1.0, u'03/04 22:59'),
#  (u'ARodGodlike', u'\u723d\u5566\x1b\r\n', 1.0, u'03/04 22:59'),
#  (u'paula12', u'wow!!!\x1b\r\n', 1.0, u'03/04 23:00'),
#  (u'gtayu', u'\u63a8\u554a\x1b\r\n', 1.0, u'03/04 23:00'),
#  (u'tritonchang',
#   u'\u6012\u5403\u6ce1\u8299\u3127\u7bb1\x1b\r\n',
#   0.0,
#   u'03/04 23:00'),
#  (u'BearCastle', u'\x1b\r\n', 1.0, u'03/04 23:00'),
#  (u'momo504131',
#   u'\u6012\u5403\u7fa9\u7f8e\u5e03\u4e01\u5566\x1b\r\n',
#   1.0,
#   u'03/04 23:01'),
#  (u'daieiso', u'\u8b9a\x1b\r\n', 1.0, u'03/04 23:01'),
#  (u'uku',
#   u'\u5c0f\u6ce1\u8299\uff0c\u9bae\u5976\u70ba\u4f55\u52a0\u78b3\u9178\u9223\x1b\r\n',
#   1.0,
#   u'03/04 23:02'),
#  (u'ptttea', u'\u63a8\x1b\r\n', 1.0, u'03/04 23:02'),
#  (u'MOSMOSQQ55',
#   u'\u5927\u5bb6\u771f\u7684\u61c2\u9019\u4efd\u540d\u55ae\u7684\u4eba\u55ce\uff1f\x1b\r\n',
#   -1.0,
#   u'03/04 23:02'),
#  (u'x137', u'\u63a8\x1b\r\n', 1.0, u'03/04 23:04'),
#  (u'uku',
#   u'\u9ad8:\u4ee5\u5f8c\u53d6\u6d88\u4fdd\u5b58\u671f\u9650\x1b\r\n',
#   0.0,
#   u'03/04 23:04'),
#  (u'jsyunlin', u'\u606d\u559c\u7fa9\u7f8e\x1b\r\n', 1.0, u'03/04 23:05'),
#  (u'uku',
#   u'\u9ad8:\u52a0\u84ec\u9b06\u5291\u624d\u662f\u5065\u5eb7\u98df\u54c1\x1b\r\n',
#   0.0,
#   u'03/04 23:05'),
#  (u'peterwww',
#   u'\u5947\u602a\u9019\u500b\u597d\u50cf\u602a\u602a\u7684\r\n',
#   0.0,
#   u'03/04 23:05'),
#  (u'xspc', u'\u63a8\x1b[23;26H\r\n', 1.0, u'03/04 23:06'),
#  (u'lioujason', u'\u63a8\x1b\r\n', 1.0, u'03/04 23:06'),
#  (u'peterwww',
#   u'\u8ca1\u5718\u7684\u4eba\u4e0d\u61c9\u8a72\u7403\u54e1\u517c\u88c1\u5224\u8981\u5c31\u63a8\u51fa\u7fa9\u7f8e\u7d93\u71df\u518d\u4f86\x1b\r\n',
#   0.0,
#   u'03/04 23:06'),
#  (u'peterwww',
#   u'\u9000\u51fa\u7fa9\u7f8e\u518d\u4f86\u7576\x1b\r\n',
#   0.0,
#   u'03/04 23:06'),
#  (u'ni1987',
#   u'\u53f0\u5317\u5e02\u805a\u96c6\u4e00\u5806\u83c1\u82f1\u4eba\u624d\u65b0\u5317\u5e02\u5728\u5e79\u561b\u5566\x1b\r\n',
#   1.0,
#   u'03/04 23:07'),
#  (u'trazom0506',
#   u'\u4e0d\u63a8\u4e0d\u884c\uff01\uff01\uff01\x1b\r\n',
#   1.0,
#   u'03/04 23:09'),
#  (u'uku',
#   u'\u5f9e\u7fa9\u7f8e\u4e8b\u4ef6\u53ef\u770b\u51fa\u7121\u77e5\u662f\u771f\u7684\uff0c\u81eahi\u5c31\u597d\x1b\r\n',
#   0.0,
#   u'03/04 23:09'),
#  (u'bubblet',
#   u'\u592a\u9177\u4e86\uff0c\u8d8a\u4f86\u8d8a\u7fa8\u6155\u53f0\u5317\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 23:09'),
#  (u'remprogress',
#   u'\u795e\u4e00\u822c\u7684\u540d\u55ae\u5e02\u9577\u9078\u5c0d\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 23:10'),
#  (u'inlanyu', u'\u63a8\x1b\r\n', 1.0, u'03/04 23:10'),
#  (u'krobenb', u'\u6c34\u5566\x1b\r\n', 1.0, u'03/04 23:11'),
#  (u'skybrest',
#   u'\u6211\u8981\u7528\u65b0\u53f0\u5e63\u62b5\u5236\u7fa9\u7f8e!!!\x1b\r\n',
#   1.0,
#   u'03/04 23:13'),
#  (u'jerry012188', u'\u6709\u5920\u795e\x1b\r\n', 0.0, u'03/04 23:13'),
#  (u'ZIQQ001',
#   u'\u8ca1\u5718\u7684\u4eba\u4e0d\u61c9\u8a72\u7403\u54e1\u517c\u88c1\u5224+1\x1b\r\n',
#   0.0,
#   u'03/04 23:14'),
#  (u'msa5566',
#   u'\u53ef\u60e1!\u6012\u8cb7\u8cb7\u4e09\u76d2\u7fa9\u7f8e\u6e6f\u5713\uff0c\u660e\u5929\u716e\u4f86\u5403\x1b\r\n',
#   1.0,
#   u'03/04 23:14'),
#  (u'tritonchang',
#   u'\u611f\u8b1dKMT\u52dd\u6587\u6b62\u5140\u6dd1\u857e\uff0c\u6c92\u4ed6\u5011\u5c31\u6c92\u6709\u67ef\u5e02\u9577\x1b\r\n',
#   1.0,
#   u'03/04 23:15'),
#  (u'chrome', u'\u63a8\x1b\r\n', 1.0, u'03/04 23:15'),
#  (u'tarbaby',
#   u'\u597d\u60f3\u642c\u53bb\u53f0\u5317\u4f4f\u5594\x1b\r\n',
#   1.0,
#   u'03/04 23:15'),
#  (u'HBK66',
#   u'\u525b\u525b\u624d\u53bb\u8cb7\u5e7e\u5305\u5c0f\u6ce1\u8299\u6559\u8a13\u7fa9\u7f8e\x1b\r\n',
#   0.0,
#   u'03/04 23:16'),
#  (u'ce270651',
#   u'\u5abd\u5abd\u554f\u6211\u70ba\u4ec0\u9ebc\u8dea\u5728\u5730\u4e0a\x1b\r\n',
#   1.0,
#   u'03/04 23:19'),
#  (u'Comebuy', u'........\u8dea\u4e86\x1b\r\n', 1.0, u'03/04 23:22'),
#  (u'billabcddog',
#   u"\u90a3\u8ddf\u99ac\u7e3d\u7d71\u7684\u98df\u5b89\u8fa6\u516c\u5ba4\u4e0d\u662f\u529f\u80fd\u91cd\u8907\u4e86\u55ceo'__'o\x1b\r\n",
#   1.0,
#   u'03/04 23:23'),
#  (u'newnewptt', u'\u6c34\u5566~~~!\r\n', 1.0, u'03/04 23:25'),
#  (u'Jinchan',
#   u'\u53bb\u8cb7\u5de7\u514b\u529b\u5de7\u8299\r\n',
#   1.0,
#   u'03/04 23:32'),
#  (u'ni1987',
#   u'\u53f0\u5317\u5e02\u805a\u96c6\u4e00\u5806\u83c1\u82f1\u4eba\u624d\u65b0\u5317\u5e02\u5728\u5e79\u561b\u5566\x1b\r\n',
#   1.0,
#   u'03/04 23:07'),
#  (u'trazom0506',
#   u'\u4e0d\u63a8\u4e0d\u884c\uff01\uff01\uff01\x1b\r\n',
#   1.0,
#   u'03/04 23:09'),
#  (u'uku',
#   u'\u5f9e\u7fa9\u7f8e\u4e8b\u4ef6\u53ef\u770b\u51fa\u7121\u77e5\u662f\u771f\u7684\uff0c\u81eahi\u5c31\u597d\x1b\r\n',
#   0.0,
#   u'03/04 23:09'),
#  (u'bubblet',
#   u'\u592a\u9177\u4e86\uff0c\u8d8a\u4f86\u8d8a\u7fa8\u6155\u53f0\u5317\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 23:09'),
#  (u'remprogress',
#   u'\u795e\u4e00\u822c\u7684\u540d\u55ae\u5e02\u9577\u9078\u5c0d\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 23:10'),
#  (u'inlanyu', u'\u63a8\x1b\r\n', 1.0, u'03/04 23:10'),
#  (u'krobenb', u'\u6c34\u5566\x1b\r\n', 1.0, u'03/04 23:11'),
#  (u'skybrest',
#   u'\u6211\u8981\u7528\u65b0\u53f0\u5e63\u62b5\u5236\u7fa9\u7f8e!!!\x1b\r\n',
#   1.0,
#   u'03/04 23:13'),
#  (u'jerry012188', u'\u6709\u5920\u795e\x1b\r\n', 0.0, u'03/04 23:13'),
#  (u'ZIQQ001',
#   u'\u8ca1\u5718\u7684\u4eba\u4e0d\u61c9\u8a72\u7403\u54e1\u517c\u88c1\u5224+1\x1b\r\n',
#   0.0,
#   u'03/04 23:14'),
#  (u'msa5566',
#   u'\u53ef\u60e1!\u6012\u8cb7\u8cb7\u4e09\u76d2\u7fa9\u7f8e\u6e6f\u5713\uff0c\u660e\u5929\u716e\u4f86\u5403\x1b\r\n',
#   1.0,
#   u'03/04 23:14'),
#  (u'tritonchang',
#   u'\u611f\u8b1dKMT\u52dd\u6587\u6b62\u5140\u6dd1\u857e\uff0c\u6c92\u4ed6\u5011\u5c31\u6c92\u6709\u67ef\u5e02\u9577\x1b\r\n',
#   1.0,
#   u'03/04 23:15'),
#  (u'chrome', u'\u63a8\x1b\r\n', 1.0, u'03/04 23:15'),
#  (u'tarbaby',
#   u'\u597d\u60f3\u642c\u53bb\u53f0\u5317\u4f4f\u5594\x1b\r\n',
#   1.0,
#   u'03/04 23:15'),
#  (u'HBK66',
#   u'\u525b\u525b\u624d\u53bb\u8cb7\u5e7e\u5305\u5c0f\u6ce1\u8299\u6559\u8a13\u7fa9\u7f8e\x1b\r\n',
#   0.0,
#   u'03/04 23:16'),
#  (u'ce270651',
#   u'\u5abd\u5abd\u554f\u6211\u70ba\u4ec0\u9ebc\u8dea\u5728\u5730\u4e0a\x1b\r\n',
#   1.0,
#   u'03/04 23:19'),
#  (u'Comebuy', u'........\u8dea\u4e86\x1b\r\n', 1.0, u'03/04 23:22'),
#  (u'billabcddog',
#   u"\u90a3\u8ddf\u99ac\u7e3d\u7d71\u7684\u98df\u5b89\u8fa6\u516c\u5ba4\u4e0d\u662f\u529f\u80fd\u91cd\u8907\u4e86\u55ceo'__'o\x1b\r\n",
#   1.0,
#   u'03/04 23:23'),
#  (u'newnewptt', u'\u6c34\u5566~~~!\x1b\r\n', 1.0, u'03/04 23:25'),
#  (u'Jinchan',
#   u'\u53bb\u8cb7\u5de7\u514b\u529b\u5de7\u8299\x1b\r\n',
#   1.0,
#   u'03/04 23:32'),
#  (u'momoisacow',
#   u'\u65e9\u8aaa\u904e\u9ad8\u96c4\u4eba\u5225\u56c2\u5f35\u4e86\x1b\r\n',
#   1.0,
#   u'03/04 23:35'),
#  (u'chunjing',
#   u'\u53c8\u662f\u7fa9\u7f8e\u223c\u53c8\u60f3\u559d\u7c73\u6f3f\u60f9\u223c\r\n',
#   1.0,
#   u'03/04 23:36'),
#  (u'hahaha129', u'\u63a8\x1b[23;26H\r\n', 1.0, u'03/04 23:38'),
#  (u'zhow', u'3cup', 1.0, u'03/04 23:39'),
#  (u'zhow', u'3cup!!!', 1.0, u'03/04 23:40'),
#  (u'zhow', u'man show gun', 1.0, u'03/04 23:40'),
#  (u'zhow', u'momo shoping', 1.0, u'03/04 23:40')]

# %%
cursor.execute("SELECT ID FROM pushdata;")
result_Ids_tuple=cursor.fetchall()

# %%
result_Ids_tuple
# Out:
# [(u'tw00527876',),
#  (u'dSnAil',),
#  (u'tetsu0401',),
#  (u'dnek',),
#  (u'lebiged',),
#  (u'zeze',),
#  (u'ddd87521',),
#  (u'yaya',),
#  (u'Doukyusei',),
#  (u'kuankubank',),
#  (u'buchholiz',),
#  (u'kiergh',),
#  (u'iXXXXGAY5566',),
#  (u'Francis11',),
#  (u'yun0215',),
#  (u'fvfv',),
#  (u'yaya',),
#  (u'creulfact',),
#  (u'meowchen',),
#  (u'LoveMakeLove',),
#  (u'yun0215',),
#  (u'greatgatsby',),
#  (u'Simakui',),
#  (u'chungyiju',),
#  (u'taimu',),
#  (u'roveralex',),
#  (u'fanlander',),
#  (u'yeahoviovi',),
#  (u'yaya',),
#  (u'jevix',),
#  (u'v19791119',),
#  (u'DFTT',),
#  (u'sa87a16',),
#  (u'chihchuan',),
#  (u'zebra7',),
#  (u'xfirex',),
#  (u'dinex',),
#  (u'fifi0828',),
#  (u'Jackyfans',),
#  (u'foolfighter',),
#  (u'pagenotfound',),
#  (u'MAGICMCGRADY',),
#  (u'dragon2000',),
#  (u'crusaders811',),
#  (u'eric2099',),
#  (u'shark5566',),
#  (u'rock666',),
#  (u'kiki2125',),
#  (u'joanying',),
#  (u'Tuscany',),
#  (u'amop',),
#  (u'shiang28',),
#  (u'headiron',),
#  (u'epistemie',),
#  (u'c10177',),
#  (u'kenyin',),
#  (u'unreal29',),
#  (u'collector',),
#  (u'ymx3xc',),
#  (u'dearevan',),
#  (u'ryan0222',),
#  (u'pagenotfound',),
#  (u'CORSA',),
#  (u'shadow666',),
#  (u'vimeo',),
#  (u'julia66',),
#  (u'dafo',),
#  (u'meowmeowgo',),
#  (u'zxcvf',),
#  (u'HornyDragon',),
#  (u'victoryman',),
#  (u'ace4',),
#  (u'higameboy',),
#  (u'oicecnir',),
#  (u'GenghisKhan',),
#  (u'blueweave',),
#  (u'leontj',),
#  (u'yduiy',),
#  (u'elle',),
#  (u'kimitoboku',),
#  (u'miloisgood',),
#  (u'jeneaqa1',),
#  (u'love1987817',),
#  (u'TIGER228',),
#  (u'weboau',),
#  (u'iMANIA',),
#  (u'ecgklf',),
#  (u'sediments',),
#  (u'skyringcha',),
#  (u'mayuyuki',),
#  (u'fytnship',),
#  (u'garcia',),
#  (u'Refauth',),
#  (u'prkfcpr',),
#  (u'harryrrah',),
#  (u'skyringcha',),
#  (u'frogha1',),
#  (u'hyperionii',),
#  (u'frogha1',),
#  (u'frogha1',),
#  (u'cychine',),
#  (u'pagenotfound',),
#  (u'pftmax',),
#  (u'embracepl',),
#  (u'dodo6',),
#  (u'cttw19',),
#  (u'Taidalmc',),
#  (u'SHIU0315',),
#  (u'Su22',),
#  (u'yeh0416',),
#  (u'deathsman',),
#  (u'ChrisLiu',),
#  (u'STi2011',),
#  (u'yaya',),
#  (u'terresa916',),
#  (u'mjumju',),
#  (u'wrbfndkdo',),
#  (u'aimgel',),
#  (u'suge',),
#  (u'guepard',),
#  (u'Lazzaro',),
#  (u'gsx7777777',),
#  (u'Jing0733',),
#  (u'allloveme',),
#  (u'Kennyq',),
#  (u'Samael',),
#  (u'tzuchun0214',),
#  (u'aa1477888',),
#  (u'abls',),
#  (u'celine1234',),
#  (u'Supasizeit',),
#  (u'VVax',),
#  (u'daniel3551',),
#  (u'fangio',),
#  (u'revive25',),
#  (u'dostey',),
#  (u'shadow77727',),
#  (u'heylisa',),
#  (u'costello',),
#  (u'alwaysstrong',),
#  (u'vgbvgb',),
#  (u'resudi',),
#  (u'lppal',),
#  (u'kducky',),
#  (u'keepsmiling',),
#  (u'kis28519',),
#  (u'wayne1120',),
#  (u'Tamama56',),
#  (u'pkyosx',),
#  (u'jiumee',),
#  (u'kktt254',),
#  (u'theEastCoast',),
#  (u'apple8335',),
#  (u'fisht',),
#  (u'keane9112',),
#  (u'shinobunodok',),
#  (u'vingfing',),
#  (u'Singlewing',),
#  (u'minbyminby',),
#  (u'krishuang',),
#  (u'rong0204',),
#  (u'DarylMorey',),
#  (u'hsm926',),
#  (u'ajin0305',),
#  (u'alibuda2014',),
#  (u'zz71',),
#  (u'richard42',),
#  (u'Asucks',),
#  (u'Asucks',),
#  (u'baddad',),
#  (u'fallen1',),
#  (u'eldar',),
#  (u'wakou109',),
#  (u'yulin0312',),
#  (u'geesegeese',),
#  (u'Azabulu',),
#  (u'maxboy06',),
#  (u'fransiceyho',),
#  (u'airflow',),
#  (u'curly7',),
#  (u'kiwiwoo',),
#  (u'htaedamay',),
#  (u'error123',),
#  (u'bloodmickey',),
#  (u'mengjertsai',),
#  (u'rainbow321',),
#  (u'behero',),
#  (u'njrmp',),
#  (u'germing',),
#  (u'germing',),
#  (u'blxbl',),
#  (u'chyou2003',),
#  (u'a2156700',),
#  (u'mmarty',),
#  (u'ARodGodlike',),
#  (u'paula12',),
#  (u'gtayu',),
#  (u'tritonchang',),
#  (u'BearCastle',),
#  (u'momo504131',),
#  (u'daieiso',),
#  (u'uku',),
#  (u'ptttea',),
#  (u'MOSMOSQQ55',),
#  (u'x137',),
#  (u'uku',),
#  (u'jsyunlin',),
#  (u'uku',),
#  (u'peterwww',),
#  (u'xspc',),
#  (u'lioujason',),
#  (u'peterwww',),
#  (u'peterwww',),
#  (u'ni1987',),
#  (u'trazom0506',),
#  (u'uku',),
#  (u'bubblet',),
#  (u'remprogress',),
#  (u'inlanyu',),
#  (u'krobenb',),
#  (u'skybrest',),
#  (u'jerry012188',),
#  (u'ZIQQ001',),
#  (u'msa5566',),
#  (u'tritonchang',),
#  (u'chrome',),
#  (u'tarbaby',),
#  (u'HBK66',),
#  (u'ce270651',),
#  (u'Comebuy',),
#  (u'billabcddog',),
#  (u'newnewptt',),
#  (u'Jinchan',),
#  (u'ni1987',),
#  (u'trazom0506',),
#  (u'uku',),
#  (u'bubblet',),
#  (u'remprogress',),
#  (u'inlanyu',),
#  (u'krobenb',),
#  (u'skybrest',),
#  (u'jerry012188',),
#  (u'ZIQQ001',),
#  (u'msa5566',),
#  (u'tritonchang',),
#  (u'chrome',),
#  (u'tarbaby',),
#  (u'HBK66',),
#  (u'ce270651',),
#  (u'Comebuy',),
#  (u'billabcddog',),
#  (u'newnewptt',),
#  (u'Jinchan',),
#  (u'momoisacow',),
#  (u'chunjing',),
#  (u'hahaha129',),
#  (u'zhow',),
#  (u'zhow',),
#  (u'zhow',),
#  (u'zhow',)]

# %%
len(result_Ids_tuple[1])
# Out:
# 1

# %%
result_Ids=[i[0] for i in result_Ids_tuple]
result_Ids
# Out:
# [u'tw00527876',
#  u'dSnAil',
#  u'tetsu0401',
#  u'dnek',
#  u'lebiged',
#  u'zeze',
#  u'ddd87521',
#  u'yaya',
#  u'Doukyusei',
#  u'kuankubank',
#  u'buchholiz',
#  u'kiergh',
#  u'iXXXXGAY5566',
#  u'Francis11',
#  u'yun0215',
#  u'fvfv',
#  u'yaya',
#  u'creulfact',
#  u'meowchen',
#  u'LoveMakeLove',
#  u'yun0215',
#  u'greatgatsby',
#  u'Simakui',
#  u'chungyiju',
#  u'taimu',
#  u'roveralex',
#  u'fanlander',
#  u'yeahoviovi',
#  u'yaya',
#  u'jevix',
#  u'v19791119',
#  u'DFTT',
#  u'sa87a16',
#  u'chihchuan',
#  u'zebra7',
#  u'xfirex',
#  u'dinex',
#  u'fifi0828',
#  u'Jackyfans',
#  u'foolfighter',
#  u'pagenotfound',
#  u'MAGICMCGRADY',
#  u'dragon2000',
#  u'crusaders811',
#  u'eric2099',
#  u'shark5566',
#  u'rock666',
#  u'kiki2125',
#  u'joanying',
#  u'Tuscany',
#  u'amop',
#  u'shiang28',
#  u'headiron',
#  u'epistemie',
#  u'c10177',
#  u'kenyin',
#  u'unreal29',
#  u'collector',
#  u'ymx3xc',
#  u'dearevan',
#  u'ryan0222',
#  u'pagenotfound',
#  u'CORSA',
#  u'shadow666',
#  u'vimeo',
#  u'julia66',
#  u'dafo',
#  u'meowmeowgo',
#  u'zxcvf',
#  u'HornyDragon',
#  u'victoryman',
#  u'ace4',
#  u'higameboy',
#  u'oicecnir',
#  u'GenghisKhan',
#  u'blueweave',
#  u'leontj',
#  u'yduiy',
#  u'elle',
#  u'kimitoboku',
#  u'miloisgood',
#  u'jeneaqa1',
#  u'love1987817',
#  u'TIGER228',
#  u'weboau',
#  u'iMANIA',
#  u'ecgklf',
#  u'sediments',
#  u'skyringcha',
#  u'mayuyuki',
#  u'fytnship',
#  u'garcia',
#  u'Refauth',
#  u'prkfcpr',
#  u'harryrrah',
#  u'skyringcha',
#  u'frogha1',
#  u'hyperionii',
#  u'frogha1',
#  u'frogha1',
#  u'cychine',
#  u'pagenotfound',
#  u'pftmax',
#  u'embracepl',
#  u'dodo6',
#  u'cttw19',
#  u'Taidalmc',
#  u'SHIU0315',
#  u'Su22',
#  u'yeh0416',
#  u'deathsman',
#  u'ChrisLiu',
#  u'STi2011',
#  u'yaya',
#  u'terresa916',
#  u'mjumju',
#  u'wrbfndkdo',
#  u'aimgel',
#  u'suge',
#  u'guepard',
#  u'Lazzaro',
#  u'gsx7777777',
#  u'Jing0733',
#  u'allloveme',
#  u'Kennyq',
#  u'Samael',
#  u'tzuchun0214',
#  u'aa1477888',
#  u'abls',
#  u'celine1234',
#  u'Supasizeit',
#  u'VVax',
#  u'daniel3551',
#  u'fangio',
#  u'revive25',
#  u'dostey',
#  u'shadow77727',
#  u'heylisa',
#  u'costello',
#  u'alwaysstrong',
#  u'vgbvgb',
#  u'resudi',
#  u'lppal',
#  u'kducky',
#  u'keepsmiling',
#  u'kis28519',
#  u'wayne1120',
#  u'Tamama56',
#  u'pkyosx',
#  u'jiumee',
#  u'kktt254',
#  u'theEastCoast',
#  u'apple8335',
#  u'fisht',
#  u'keane9112',
#  u'shinobunodok',
#  u'vingfing',
#  u'Singlewing',
#  u'minbyminby',
#  u'krishuang',
#  u'rong0204',
#  u'DarylMorey',
#  u'hsm926',
#  u'ajin0305',
#  u'alibuda2014',
#  u'zz71',
#  u'richard42',
#  u'Asucks',
#  u'Asucks',
#  u'baddad',
#  u'fallen1',
#  u'eldar',
#  u'wakou109',
#  u'yulin0312',
#  u'geesegeese',
#  u'Azabulu',
#  u'maxboy06',
#  u'fransiceyho',
#  u'airflow',
#  u'curly7',
#  u'kiwiwoo',
#  u'htaedamay',
#  u'error123',
#  u'bloodmickey',
#  u'mengjertsai',
#  u'rainbow321',
#  u'behero',
#  u'njrmp',
#  u'germing',
#  u'germing',
#  u'blxbl',
#  u'chyou2003',
#  u'a2156700',
#  u'mmarty',
#  u'ARodGodlike',
#  u'paula12',
#  u'gtayu',
#  u'tritonchang',
#  u'BearCastle',
#  u'momo504131',
#  u'daieiso',
#  u'uku',
#  u'ptttea',
#  u'MOSMOSQQ55',
#  u'x137',
#  u'uku',
#  u'jsyunlin',
#  u'uku',
#  u'peterwww',
#  u'xspc',
#  u'lioujason',
#  u'peterwww',
#  u'peterwww',
#  u'ni1987',
#  u'trazom0506',
#  u'uku',
#  u'bubblet',
#  u'remprogress',
#  u'inlanyu',
#  u'krobenb',
#  u'skybrest',
#  u'jerry012188',
#  u'ZIQQ001',
#  u'msa5566',
#  u'tritonchang',
#  u'chrome',
#  u'tarbaby',
#  u'HBK66',
#  u'ce270651',
#  u'Comebuy',
#  u'billabcddog',
#  u'newnewptt',
#  u'Jinchan',
#  u'ni1987',
#  u'trazom0506',
#  u'uku',
#  u'bubblet',
#  u'remprogress',
#  u'inlanyu',
#  u'krobenb',
#  u'skybrest',
#  u'jerry012188',
#  u'ZIQQ001',
#  u'msa5566',
#  u'tritonchang',
#  u'chrome',
#  u'tarbaby',
#  u'HBK66',
#  u'ce270651',
#  u'Comebuy',
#  u'billabcddog',
#  u'newnewptt',
#  u'Jinchan',
#  u'momoisacow',
#  u'chunjing',
#  u'hahaha129',
#  u'zhow',
#  u'zhow',
#  u'zhow',
#  u'zhow']

# %%
wordCount=dict()
for i in result_Ids:
    wordCount[i]=wordCount.get(i,0)+1

# %%
wordCount
# Out:
# {u'ARodGodlike': 1,
#  u'Asucks': 2,
#  u'Azabulu': 1,
#  u'BearCastle': 1,
#  u'CORSA': 1,
#  u'ChrisLiu': 1,
#  u'Comebuy': 2,
#  u'DFTT': 1,
#  u'DarylMorey': 1,
#  u'Doukyusei': 1,
#  u'Francis11': 1,
#  u'GenghisKhan': 1,
#  u'HBK66': 2,
#  u'HornyDragon': 1,
#  u'Jackyfans': 1,
#  u'Jinchan': 2,
#  u'Jing0733': 1,
#  u'Kennyq': 1,
#  u'Lazzaro': 1,
#  u'LoveMakeLove': 1,
#  u'MAGICMCGRADY': 1,
#  u'MOSMOSQQ55': 1,
#  u'Refauth': 1,
#  u'SHIU0315': 1,
#  u'STi2011': 1,
#  u'Samael': 1,
#  u'Simakui': 1,
#  u'Singlewing': 1,
#  u'Su22': 1,
#  u'Supasizeit': 1,
#  u'TIGER228': 1,
#  u'Taidalmc': 1,
#  u'Tamama56': 1,
#  u'Tuscany': 1,
#  u'VVax': 1,
#  u'ZIQQ001': 2,
#  u'a2156700': 1,
#  u'aa1477888': 1,
#  u'abls': 1,
#  u'ace4': 1,
#  u'aimgel': 1,
#  u'airflow': 1,
#  u'ajin0305': 1,
#  u'alibuda2014': 1,
#  u'allloveme': 1,
#  u'alwaysstrong': 1,
#  u'amop': 1,
#  u'apple8335': 1,
#  u'baddad': 1,
#  u'behero': 1,
#  u'billabcddog': 2,
#  u'bloodmickey': 1,
#  u'blueweave': 1,
#  u'blxbl': 1,
#  u'bubblet': 2,
#  u'buchholiz': 1,
#  u'c10177': 1,
#  u'ce270651': 2,
#  u'celine1234': 1,
#  u'chihchuan': 1,
#  u'chrome': 2,
#  u'chungyiju': 1,
#  u'chunjing': 1,
#  u'chyou2003': 1,
#  u'collector': 1,
#  u'costello': 1,
#  u'creulfact': 1,
#  u'crusaders811': 1,
#  u'cttw19': 1,
#  u'curly7': 1,
#  u'cychine': 1,
#  u'dSnAil': 1,
#  u'dafo': 1,
#  u'daieiso': 1,
#  u'daniel3551': 1,
#  u'ddd87521': 1,
#  u'dearevan': 1,
#  u'deathsman': 1,
#  u'dinex': 1,
#  u'dnek': 1,
#  u'dodo6': 1,
#  u'dostey': 1,
#  u'dragon2000': 1,
#  u'ecgklf': 1,
#  u'eldar': 1,
#  u'elle': 1,
#  u'embracepl': 1,
#  u'epistemie': 1,
#  u'eric2099': 1,
#  u'error123': 1,
#  u'fallen1': 1,
#  u'fangio': 1,
#  u'fanlander': 1,
#  u'fifi0828': 1,
#  u'fisht': 1,
#  u'foolfighter': 1,
#  u'fransiceyho': 1,
#  u'frogha1': 3,
#  u'fvfv': 1,
#  u'fytnship': 1,
#  u'garcia': 1,
#  u'geesegeese': 1,
#  u'germing': 2,
#  u'greatgatsby': 1,
#  u'gsx7777777': 1,
#  u'gtayu': 1,
#  u'guepard': 1,
#  u'hahaha129': 1,
#  u'harryrrah': 1,
#  u'headiron': 1,
#  u'heylisa': 1,
#  u'higameboy': 1,
#  u'hsm926': 1,
#  u'htaedamay': 1,
#  u'hyperionii': 1,
#  u'iMANIA': 1,
#  u'iXXXXGAY5566': 1,
#  u'inlanyu': 2,
#  u'jeneaqa1': 1,
#  u'jerry012188': 2,
#  u'jevix': 1,
#  u'jiumee': 1,
#  u'joanying': 1,
#  u'jsyunlin': 1,
#  u'julia66': 1,
#  u'kducky': 1,
#  u'keane9112': 1,
#  u'keepsmiling': 1,
#  u'kenyin': 1,
#  u'kiergh': 1,
#  u'kiki2125': 1,
#  u'kimitoboku': 1,
#  u'kis28519': 1,
#  u'kiwiwoo': 1,
#  u'kktt254': 1,
#  u'krishuang': 1,
#  u'krobenb': 2,
#  u'kuankubank': 1,
#  u'lebiged': 1,
#  u'leontj': 1,
#  u'lioujason': 1,
#  u'love1987817': 1,
#  u'lppal': 1,
#  u'maxboy06': 1,
#  u'mayuyuki': 1,
#  u'mengjertsai': 1,
#  u'meowchen': 1,
#  u'meowmeowgo': 1,
#  u'miloisgood': 1,
#  u'minbyminby': 1,
#  u'mjumju': 1,
#  u'mmarty': 1,
#  u'momo504131': 1,
#  u'momoisacow': 1,
#  u'msa5566': 2,
#  u'newnewptt': 2,
#  u'ni1987': 2,
#  u'njrmp': 1,
#  u'oicecnir': 1,
#  u'pagenotfound': 3,
#  u'paula12': 1,
#  u'peterwww': 3,
#  u'pftmax': 1,
#  u'pkyosx': 1,
#  u'prkfcpr': 1,
#  u'ptttea': 1,
#  u'rainbow321': 1,
#  u'remprogress': 2,
#  u'resudi': 1,
#  u'revive25': 1,
#  u'richard42': 1,
#  u'rock666': 1,
#  u'rong0204': 1,
#  u'roveralex': 1,
#  u'ryan0222': 1,
#  u'sa87a16': 1,
#  u'sediments': 1,
#  u'shadow666': 1,
#  u'shadow77727': 1,
#  u'shark5566': 1,
#  u'shiang28': 1,
#  u'shinobunodok': 1,
#  u'skybrest': 2,
#  u'skyringcha': 2,
#  u'suge': 1,
#  u'taimu': 1,
#  u'tarbaby': 2,
#  u'terresa916': 1,
#  u'tetsu0401': 1,
#  u'theEastCoast': 1,
#  u'trazom0506': 2,
#  u'tritonchang': 3,
#  u'tw00527876': 1,
#  u'tzuchun0214': 1,
#  u'uku': 5,
#  u'unreal29': 1,
#  u'v19791119': 1,
#  u'vgbvgb': 1,
#  u'victoryman': 1,
#  u'vimeo': 1,
#  u'vingfing': 1,
#  u'wakou109': 1,
#  u'wayne1120': 1,
#  u'weboau': 1,
#  u'wrbfndkdo': 1,
#  u'x137': 1,
#  u'xfirex': 1,
#  u'xspc': 1,
#  u'yaya': 4,
#  u'yduiy': 1,
#  u'yeahoviovi': 1,
#  u'yeh0416': 1,
#  u'ymx3xc': 1,
#  u'yulin0312': 1,
#  u'yun0215': 2,
#  u'zebra7': 1,
#  u'zeze': 1,
#  u'zhow': 4,
#  u'zxcvf': 1,
#  u'zz71': 1}

# %%
wordCount.items()[1:5]
# Out:
# [(u'minbyminby', 1), (u'higameboy', 1), (u'foolfighter', 1), (u'Taidalmc', 1)]

# %%
#http://stackoverflow.com/questions/613183/sort-a-python-dictionary-by-value
import operator
sorted_x = sorted(wordCount.items(), key=operator.itemgetter(1),reverse=True)[:5]
sorted_x
# Out:
# [(u'uku', 5),
#  (u'yaya', 4),
#  (u'zhow', 4),
#  (u'peterwww', 3),
#  (u'pagenotfound', 3)]

# %%
#https://docs.python.org/2/howto/sorting.html
topfive_id=sorted(wordCount.items(),key=lambda x:x[1],reverse=True)[:5]
print topfive_id
# Out:
# [(u'uku', 5), (u'yaya', 4), (u'zhow', 4), (u'peterwww', 3), (u'pagenotfound', 3)]

# %% [markdown]
# ## select from where

# %%
cursor.execute("SELECT pushsb,ID FROM pushdata WHERE pushsb=1;")
results=cursor.fetchall()

# %%
results
# Out:
# [(1.0, u'tw00527876'),
#  (1.0, u'dSnAil'),
#  (1.0, u'tetsu0401'),
#  (1.0, u'lebiged'),
#  (1.0, u'Doukyusei'),
#  (1.0, u'buchholiz'),
#  (1.0, u'kiergh'),
#  (1.0, u'Francis11'),
#  (1.0, u'yun0215'),
#  (1.0, u'fvfv'),
#  (1.0, u'yaya'),
#  (1.0, u'creulfact'),
#  (1.0, u'meowchen'),
#  (1.0, u'LoveMakeLove'),
#  (1.0, u'greatgatsby'),
#  (1.0, u'Simakui'),
#  (1.0, u'chungyiju'),
#  (1.0, u'taimu'),
#  (1.0, u'roveralex'),
#  (1.0, u'fanlander'),
#  (1.0, u'yeahoviovi'),
#  (1.0, u'yaya'),
#  (1.0, u'jevix'),
#  (1.0, u'v19791119'),
#  (1.0, u'sa87a16'),
#  (1.0, u'chihchuan'),
#  (1.0, u'zebra7'),
#  (1.0, u'xfirex'),
#  (1.0, u'dinex'),
#  (1.0, u'fifi0828'),
#  (1.0, u'Jackyfans'),
#  (1.0, u'pagenotfound'),
#  (1.0, u'MAGICMCGRADY'),
#  (1.0, u'dragon2000'),
#  (1.0, u'crusaders811'),
#  (1.0, u'eric2099'),
#  (1.0, u'shark5566'),
#  (1.0, u'rock666'),
#  (1.0, u'kiki2125'),
#  (1.0, u'joanying'),
#  (1.0, u'Tuscany'),
#  (1.0, u'amop'),
#  (1.0, u'shiang28'),
#  (1.0, u'headiron'),
#  (1.0, u'c10177'),
#  (1.0, u'kenyin'),
#  (1.0, u'unreal29'),
#  (1.0, u'collector'),
#  (1.0, u'ymx3xc'),
#  (1.0, u'dearevan'),
#  (1.0, u'pagenotfound'),
#  (1.0, u'shadow666'),
#  (1.0, u'vimeo'),
#  (1.0, u'julia66'),
#  (1.0, u'meowmeowgo'),
#  (1.0, u'zxcvf'),
#  (1.0, u'HornyDragon'),
#  (1.0, u'victoryman'),
#  (1.0, u'higameboy'),
#  (1.0, u'oicecnir'),
#  (1.0, u'blueweave'),
#  (1.0, u'leontj'),
#  (1.0, u'yduiy'),
#  (1.0, u'elle'),
#  (1.0, u'kimitoboku'),
#  (1.0, u'miloisgood'),
#  (1.0, u'jeneaqa1'),
#  (1.0, u'love1987817'),
#  (1.0, u'TIGER228'),
#  (1.0, u'weboau'),
#  (1.0, u'iMANIA'),
#  (1.0, u'ecgklf'),
#  (1.0, u'sediments'),
#  (1.0, u'skyringcha'),
#  (1.0, u'mayuyuki'),
#  (1.0, u'fytnship'),
#  (1.0, u'garcia'),
#  (1.0, u'Refauth'),
#  (1.0, u'prkfcpr'),
#  (1.0, u'harryrrah'),
#  (1.0, u'skyringcha'),
#  (1.0, u'hyperionii'),
#  (1.0, u'cychine'),
#  (1.0, u'pftmax'),
#  (1.0, u'embracepl'),
#  (1.0, u'dodo6'),
#  (1.0, u'cttw19'),
#  (1.0, u'Taidalmc'),
#  (1.0, u'SHIU0315'),
#  (1.0, u'Su22'),
#  (1.0, u'yeh0416'),
#  (1.0, u'deathsman'),
#  (1.0, u'ChrisLiu'),
#  (1.0, u'yaya'),
#  (1.0, u'terresa916'),
#  (1.0, u'mjumju'),
#  (1.0, u'wrbfndkdo'),
#  (1.0, u'aimgel'),
#  (1.0, u'suge'),
#  (1.0, u'guepard'),
#  (1.0, u'Lazzaro'),
#  (1.0, u'gsx7777777'),
#  (1.0, u'Jing0733'),
#  (1.0, u'allloveme'),
#  (1.0, u'Kennyq'),
#  (1.0, u'Samael'),
#  (1.0, u'tzuchun0214'),
#  (1.0, u'aa1477888'),
#  (1.0, u'abls'),
#  (1.0, u'celine1234'),
#  (1.0, u'Supasizeit'),
#  (1.0, u'VVax'),
#  (1.0, u'daniel3551'),
#  (1.0, u'fangio'),
#  (1.0, u'revive25'),
#  (1.0, u'dostey'),
#  (1.0, u'shadow77727'),
#  (1.0, u'heylisa'),
#  (1.0, u'costello'),
#  (1.0, u'vgbvgb'),
#  (1.0, u'resudi'),
#  (1.0, u'lppal'),
#  (1.0, u'kducky'),
#  (1.0, u'keepsmiling'),
#  (1.0, u'kis28519'),
#  (1.0, u'wayne1120'),
#  (1.0, u'Tamama56'),
#  (1.0, u'pkyosx'),
#  (1.0, u'jiumee'),
#  (1.0, u'kktt254'),
#  (1.0, u'theEastCoast'),
#  (1.0, u'apple8335'),
#  (1.0, u'fisht'),
#  (1.0, u'keane9112'),
#  (1.0, u'shinobunodok'),
#  (1.0, u'vingfing'),
#  (1.0, u'Singlewing'),
#  (1.0, u'minbyminby'),
#  (1.0, u'rong0204'),
#  (1.0, u'DarylMorey'),
#  (1.0, u'hsm926'),
#  (1.0, u'ajin0305'),
#  (1.0, u'alibuda2014'),
#  (1.0, u'Asucks'),
#  (1.0, u'fallen1'),
#  (1.0, u'eldar'),
#  (1.0, u'wakou109'),
#  (1.0, u'yulin0312'),
#  (1.0, u'geesegeese'),
#  (1.0, u'Azabulu'),
#  (1.0, u'maxboy06'),
#  (1.0, u'fransiceyho'),
#  (1.0, u'curly7'),
#  (1.0, u'kiwiwoo'),
#  (1.0, u'htaedamay'),
#  (1.0, u'error123'),
#  (1.0, u'bloodmickey'),
#  (1.0, u'mengjertsai'),
#  (1.0, u'rainbow321'),
#  (1.0, u'behero'),
#  (1.0, u'njrmp'),
#  (1.0, u'germing'),
#  (1.0, u'blxbl'),
#  (1.0, u'chyou2003'),
#  (1.0, u'mmarty'),
#  (1.0, u'ARodGodlike'),
#  (1.0, u'paula12'),
#  (1.0, u'gtayu'),
#  (1.0, u'BearCastle'),
#  (1.0, u'momo504131'),
#  (1.0, u'daieiso'),
#  (1.0, u'uku'),
#  (1.0, u'ptttea'),
#  (1.0, u'x137'),
#  (1.0, u'jsyunlin'),
#  (1.0, u'xspc'),
#  (1.0, u'lioujason'),
#  (1.0, u'ni1987'),
#  (1.0, u'trazom0506'),
#  (1.0, u'bubblet'),
#  (1.0, u'remprogress'),
#  (1.0, u'inlanyu'),
#  (1.0, u'krobenb'),
#  (1.0, u'skybrest'),
#  (1.0, u'msa5566'),
#  (1.0, u'tritonchang'),
#  (1.0, u'chrome'),
#  (1.0, u'tarbaby'),
#  (1.0, u'ce270651'),
#  (1.0, u'Comebuy'),
#  (1.0, u'billabcddog'),
#  (1.0, u'newnewptt'),
#  (1.0, u'Jinchan'),
#  (1.0, u'ni1987'),
#  (1.0, u'trazom0506'),
#  (1.0, u'bubblet'),
#  (1.0, u'remprogress'),
#  (1.0, u'inlanyu'),
#  (1.0, u'krobenb'),
#  (1.0, u'skybrest'),
#  (1.0, u'msa5566'),
#  (1.0, u'tritonchang'),
#  (1.0, u'chrome'),
#  (1.0, u'tarbaby'),
#  (1.0, u'ce270651'),
#  (1.0, u'Comebuy'),
#  (1.0, u'billabcddog'),
#  (1.0, u'newnewptt'),
#  (1.0, u'Jinchan'),
#  (1.0, u'momoisacow'),
#  (1.0, u'chunjing'),
#  (1.0, u'hahaha129'),
#  (1.0, u'zhow'),
#  (1.0, u'zhow'),
#  (1.0, u'zhow'),
#  (1.0, u'zhow')]

# %% [markdown]
# ## Insert

# %%
# Insert into pushdata (text,text,real,text)
pushMessage = ('zhow', '3cup' , 1, '03/04 23:39')    
cursor.execute('INSERT INTO pushdata VALUES (?,?,?,?)', pushMessage)

# %%
con.commit()

# %%
#once more queries
pushMessages = [('zhow', '3cup!!!' , 1, '03/04 23:40'),
                ('zhow', 'man show gun' , 1, '03/04 23:40'),
                ('zhow', 'momo shoping' , 1, '03/04 23:40')]

cursor.executemany('INSERT INTO pushdata VALUES (?,?,?,?)', pushMessages)
con.commit()

# %% [markdown]
# ## Delete

# %%
cursor.execute('DELETE FROM pushdata WHERE ID="zhow";')

# %%
con.commit()

# %% [markdown]
# ## create table

# %%
cursor.execute('''CREATE TABLE fequent_ID(ID text, times real)''')
con.commit()

# %%
print topfive_id
# Out:
# [(u'uku', 5), (u'yaya', 4), (u'zhow', 4), (u'peterwww', 3), (u'pagenotfound', 3)]

# %%
cursor.executemany('INSERT INTO fequent_ID VALUES (?,?)', topfive_id)
con.commit()

# %% [markdown]
# # cut the chinese words!!!
# https://github.com/fxsjy/jieba
#
# pip install jieba

# %%
# encoding=utf-8
import jieba

seg_list = jieba.cut("我来到北京清华大学", cut_all=True)
print("Full Mode: " + "/ ".join(seg_list))  # 全模式

seg_list = jieba.cut("我来到北京清华大学", cut_all=False)
print("Default Mode: " + "/ ".join(seg_list))  # 精确模式
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 1.959 seconds.
# Prefix dict has been built succesfully.
# Full Mode: 我/ 来到/ 北京/ 清华/ 清华大学/ 华大/ 大学
# Default Mode: 我/ 来到/ 北京/ 清华大学

# %%
seg_list = jieba.cut("永藍叫貢九逃", cut_all=False)
print("Default Mode: " + "/ ".join(seg_list))  # 精确模式
# Out:
# Default Mode: 永藍/ 叫/ 貢九逃

# %%
cursor.execute("SELECT * FROM pushdata WHERE rowid=234;")

results=cursor.fetchall()

# %%
print results[0][1]
print type(results[0][1])
print type("永藍叫貢九逃")
results[0][1]

# %%
seg_list = jieba.cut(results[0][1], cut_all=False)
print("Default Mode: " + "/ ".join(seg_list))  # 精确模式
# Out:
# Default Mode: 台北市/ 聚集/ 一堆/ 菁英/ 人才/ 新北市/ 在/ 幹/ 嘛/ 啦/ /

# %% [markdown]
# # Excersice
#
# (a) plz give me top five fequenct word of 3/05(rowid <=5183)
#
# (b) plz create a table records 3/05's top five fequently pushed word with (Data text, Word text, times real)
#
# (c) using excutemany to insert into DB
#
# (d) delete the rows you add in (by rowid/date)

# %% [markdown]
# ## select from DB

# %%
################### You should feed SQL here########################
cursor.execute("")
################### You should feed SQL here########################

results=cursor.fetchall()
len(results)

# %%
#string processing
print results[0][2]
print results[1][2]
print results[0][2].replace(': ','')
print results[1][2].replace(': ','')
# Out:
# : 你贏惹
# : 這張真的很讚
# 你贏惹
# 這張真的很讚

# %%
#cut the words
processed_results=[jieba.lcut(i[2].replace(':',''), cut_all=False) for i in results]

# %%
for i in processed_results[0]:
    print i
# Out:
#
# 你
# 贏惹

# %%
wordCount=dict()
for i in processed_results:
    for j in i:
        wordCount[j]=wordCount.get(j,0)+1

# %%
topfive_id=sorted(wordCount.items(),key=lambda x:x[1],reverse=True)[:15]
for i in  topfive_id:
    print i[0]+" "+str(i[1])
# Out:
#   7673
# 的 1069
# ! 792
# 了 735
# ， 553
# 是 448
# 你 418
# ~ 410
# 我 311
# 有 310
# ！ 310
# ? 307
# 推 264
# 好 249
# 就 245

# %% [markdown]
# ## There are too many garbege

# %%
stopw = [line.strip().decode('utf-8') for line in open('stop_words.txt').readlines()]
stopw[:5]
# Out:
# [u'the', u'of', u'is', u'and', u'to']

# %%
def list_rm_stops(x):
    return list(set(x)-set(stopw))

# %%
# remove the useless words!!
jieba.add_word('馬英九')
processed_results=[list_rm_stops(jieba.lcut(i[2].replace(':',''), cut_all=False)) for i in results]

# %%
wordCount=dict()
for i in processed_results:
    for j in i:
        if j!=' ':
            wordCount[j]=wordCount.get(j,0)+1
topfive_id=sorted(wordCount.items(),key=lambda x:x[1],reverse=True)[:15]
for i in  topfive_id:
    print i[0]+" "+str(i[1])
# Out:
# 推 264
# 幹 172
# 高調 105
# 房東 93
# XD 91
# 努力 85
# 2.0 65
# 崩潰 61
# 輕人 57
# 幫高調 55
# po 53
# 做 51
# 馬 51
# 一堆 51
# 自己 51

# %% [markdown]
# ### (b)create table

# %%
################### You should feed SQL here########################
cursor.execute("")
################### You should feed SQL here########################
con.commit()

# %% [markdown]
# ### (c)insert table

# %%
################### You should feed SQL here########################
cursor.execute("")
################### You should feed SQL here########################
con.commit()

# %% [markdown]
# ### (d)del table

# %%
################### You should feed SQL here########################
cursor.execute("")
################### You should feed SQL here########################
con.commit()
